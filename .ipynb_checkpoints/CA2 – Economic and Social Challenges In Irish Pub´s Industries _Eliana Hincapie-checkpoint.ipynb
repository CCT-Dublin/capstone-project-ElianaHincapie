# %% [markdown]
# # Economic and Social Challenges In Irish Pub´s Industries
# #### Eliana Hincapié

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
# %matplotlib inline

# Load the image
img=mpimg.imread('Good_Puzzle.jpeg')
plt.figure(figsize=(6, 12))
plt.axis('off')
plt.imshow(img)
